# %% [markdown]
# # Using the WRDS Platform for Compustat Data
# Src Documentation:
#     - https://wrds-www.wharton.upenn.edu/documents/1443/wrds_connection.html
#     - https://wrds-www.wharton.upenn.edu/pages/support/programming-wrds/programming-python/querying-wrds-data-python/
#     - https://pypi.org/project/wrds/

# %%
import wrds
# Sets up the connection, creates a pgpass file
conn = wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
conn.list_libraries().sort()
#type(conn.list_libraries())

# %%
# List all datasets within a given library
conn.list_tables(library='comp_na_daily_all')
# Out:
# ['aco_amda',
#  'aco_imda',
#  'aco_indfnta',
#  'aco_indfntq',
#  'aco_indfntytd',
#  'aco_indsta',
#  'aco_indstq',
#  'aco_indstytd',
#  'aco_notesa',
#  'aco_notesq',
#  'aco_notessa',
#  'aco_notesytd',
#  'aco_pnfnda',
#  'aco_pnfndq',
#  'aco_pnfndytd',
#  'aco_pnfnta',
#  'aco_pnfntq',
#  'aco_pnfntytd',
#  'aco_transa',
#  'aco_transq',
#  'aco_transsa',
#  'aco_transytd',
#  'adsprate',
#  'asec_amda',
#  'asec_imda',
#  'asec_notesa',
#  'asec_notesq',
#  'asec_transa',
#  'asec_transq',
#  'chars',
#  'co_aacctchg',
#  'co_aaudit',
#  'co_adesind',
#  'co_adjfact',
#  'co_afnd1',
#  'co_afnd2',
#  'co_afnddc1',
#  'co_afnddc2',
#  'co_afntind1',
#  'co_afntind2',
#  'co_ainvval',
#  'co_amkt',
#  'co_busdescl',
#  'co_cotype',
#  'co_filedate',
#  'co_fortune',
#  'co_hgic',
#  'co_iacctchg',
#  'co_iaudit',
#  'co_idesind',
#  'co_ifndq',
#  'co_ifndsa',
#  'co_ifndytd',
#  'co_ifntq',
#  'co_ifntsa',
#  'co_ifntytd',
#  'co_imkt',
#  'co_industry',
#  'co_ipcd',
# ...

# %% [markdown]
# 5. Query Data from WRDS Server
# - get_table() method
# - straightforward if getting data from one single dataset
# - specify which library/database and table/dataset to "get"
# - can slice data by:
#         number of rows
#         column names

# %%
# Sample to query data from WRDS server

# %%
# Extract first 5 obs from comp.company

company = conn.get_table(library='comp', table='company', obs=5)
company.shape
# Out:
# (5, 39)

# %%
company
# Out:
#                       conm   gvkey                                      add1  \
# 0    A & E PLASTIK PAK INC  001000                                      None
# 1  A & M FOOD SERVICES INC  001001                   1924 South Utica Avenue
# 2                 AAI CORP  001002                         124 Industry Lane
# 3    A.A. IMPORTING CO INC  001003                          7700 Hall Street
# 4                 AAR CORP  001004  One AAR Place, 1100 North Wood Dale Road
#
#    add2  add3  add4      addzip  \
# 0  None  None  None        None
# 1  None  None  None       94104
# 2  None  None  None  21030-0126
# 3  None  None  None       63125
# 4  None  None  None       60191
#
#                                              busdesc         cik         city  \
# 0  A & E Plastik Pak Inc. is a commodity chemical...        None         None
# 1                                               None  0000723576        Tulsa
# ...

# %%
# Uses permno sample
apple = conn.raw_sql("""select permno, date, prc, ret, shrout 
                        from crsp.msf 
                        where permno = 14593
                        and date>='01/01/2019'""", 
                     date_cols=['date'])
apple

# %%
# Table Values:
'''
    tic : ticker
    busdesc : business description
    cusip : cusip
    loc : current iso country code (HQ)
    gind : gics industries
    gsector : gics sector
    div : dividend or divd : cash dividends daily
    prccd : price close daily
    prchd : price high daily
    prcld : price low daily
    prcod : price open daily
    trfd : daily total return factor
'''
apple = conn.raw_sql("""select tic
                        from comp_na_daily_all.security 
                        where tic = 'AAPL'
                        """, 
                     date_cols=['date'])

# %%
apple
# Out:
#     tic
# 0  AAPL
