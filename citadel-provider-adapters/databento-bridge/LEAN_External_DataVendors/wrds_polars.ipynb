# %% [markdown]
# Original Code. Breakdown into steps, redo the queries as they dont work currently.

# %%
import wrds
import polars as pl

def connect_to_wrds():
    # Connect to WRDS using your credentials
    conn = wrds.Connection()
    return conn

# %%
# Converter from ticker to permno and gvkey

# Example query to get ticker data, gvkey, and permno from Compustat
def get_gvkey_permno(conn, tickers, start_date, end_date):
    # Connect to WRDS
    
    query = """
    SELECT tic, gvkey, permno
    FROM comp.security
    WHERE tic IS NOT NULL AND gvkey IS NOT NULL AND permno IS NOT NULL
    """
    
    data = conn.raw_sql(query)
    return data

# Example usage
conn = connect_to_wrds()
tickers = ['AAPL']
get_gvkey_permno(conn, tickers, '2023-01-01', '2023-09-01')
# Out:
# WRDS recommends setting up a .pgpass file.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File c:\Users\MP\anaconda3\envs\lean_datafeed\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\MP\anaconda3\envs\lean_datafeed\Lib\site-packages\sqlalchemy\engine\default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# ...

# %%
def get_ohlcv_data(conn, tickers, start_date, end_date):
    # Query CRSP for OHLCV data (daily)
    query = f"""
        SELECT date, security.tic, permno, cusip, prc AS close, 
               bidlo AS low, askhi AS high, vol AS volume, openprc AS open
        FROM crsp.dsf
        WHERE security.tic IN ({','.join([f"'{ticker}'" for ticker in tickers])})
          AND date BETWEEN '{start_date}' AND '{end_date}'
        ORDER BY date
    """
    
    data = conn.raw_sql(query)
    return data

def convert_to_polars(data):
    # Convert to Polars DataFrame
    df = pl.DataFrame(data)
    
    # Ensure the date is in the correct format
    df = df.with_columns(df['date'].str.strptime(pl.Date, format='%Y-%m-%d'))
    
    return df

# %%
def convert_to_lean_format_polars(df, ticker, frequency='daily'):
    # Ensure correct order of columns
    df = df.select(['date', 'open', 'high', 'low', 'close', 'volume'])
    
    # Convert date to the required format (YYYYMMDD)
    df = df.with_columns(df['date'].dt.strftime('%Y%m%d').alias('date'))
    
    # Save to the appropriate location
    if frequency == 'daily':
        output_file = f"data/equity/usa/daily/{ticker}.csv"
    elif frequency == 'hourly':
        output_file = f"data/equity/usa/hourly/{ticker}.csv"
    else:
        output_file = f"data/equity/usa/minute/{ticker}.zip"

    # Save as CSV in the required format
    df.write_csv(output_file)

# %%
def wrds_pipeline(tickers, start_date, end_date, frequency='daily'):
    # Connect to WRDS
    conn = connect_to_wrds()
    
    for ticker in tickers:
        # Get OHLCV data
        raw_data = get_ohlcv_data(conn, [ticker], start_date, end_date)
        
        # Convert to Polars DataFrame
        df_polars = convert_to_polars(raw_data)
        
        # Convert and save in LEAN format
        convert_to_lean_format_polars(df_polars, ticker, frequency)
    
    # Close the connection when done
    conn.close()

# Example usage
tickers = ['AAPL']
wrds_pipeline(tickers, '2023-01-01', '2023-09-01', 'daily')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\MP\anaconda3\envs\lean_datafeed\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\MP\anaconda3\envs\lean_datafeed\Lib\site-packages\sqlalchemy\engine\base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File c:\Users\MP\anaconda3\envs\lean_datafeed\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
# ...
